# %%
import pandas as pd

# %%
df = pd.read_csv('data_safe_copy.csv', parse_dates=["Date"], na_values=["NA", "NULL", "-"], index_col='Date')

# %%
df = df.sort_index()

# %%
fx = df.copy()

# %%
fx.dtypes
# Out:
# EURUSD    float64
# GBPUSD    float64
# PLNUSD    float64
# USDPLN    float64
# USDJPY    float64
# AUDUSD    float64
# NZDUSD    float64
# USDCAD    float64
# USDCHF    float64
# EURPLN    float64
# GBPPLN    float64
# dtype: object

# %%
fx
# Out:
#              EURUSD   GBPUSD    PLNUSD   USDPLN    USDJPY   AUDUSD   NZDUSD  \
# Date
# 2025-01-02  1.02661  1.23826  0.240270  4.16199  157.4610  0.62033  0.55966
# 2025-01-03  1.03062  1.24267  0.241453  4.14160  157.3420  0.62176  0.56089
# 2025-01-06  1.03900  1.25188  0.244290  4.09350  157.6200  0.62427  0.56402
# 2025-01-07  1.03426  1.24771  0.242804  4.11855  158.0405  0.62326  0.56331
# 2025-01-08  1.03185  1.23638  0.241377  4.14290  158.3085  0.62132  0.56058
# ...             ...      ...       ...      ...       ...      ...      ...
# 2026-01-26  1.18777  1.36768  0.282362  3.54155  154.1550  0.69100  0.59697
# 2026-01-27  1.20426  1.38461  0.286789  3.48689  152.3020  0.70092  0.60433
# 2026-01-28  1.19562  1.38024  0.284316  3.51721  153.4235  0.70384  0.60594
# 2026-01-29  1.19695  1.38095  0.284600  3.51370  153.0050  0.70497  0.60751
# 2026-01-30  1.18534  1.36839  0.281465  3.55284  154.7785  0.69637  0.60212
#
#              USDCAD   USDCHF   EURPLN   GBPPLN
# Date
# 2025-01-02  1.44067  0.91210  4.27274  5.15363
# 2025-01-03  1.44467  0.90891  4.26841  5.14664
# 2025-01-06  1.43330  0.90478  4.25315  5.12457
# 2025-01-07  1.43683  0.90937  4.25965  5.13875
# 2025-01-08  1.43758  0.91101  4.27485  5.12220
# ...             ...      ...      ...      ...
# 2026-01-26  1.37115  0.77720  4.20655  4.84370
# 2026-01-27  1.35758  0.76114  4.19912  4.82798
# 2026-01-28  1.35621  0.76859  4.20524  4.85459
# 2026-01-29  1.34872  0.76476  4.20572  4.85224
# 2026-01-30  1.36162  0.77302  4.21132  4.86167
#
# [280 rows x 11 columns]

# %% [markdown]
# # Task 2
# Select two currency pairs, one that ends with USD and one that begins with USD. Create a line plot for each pair over time. Add clear titles and labels. Then create a third plot that shows both series together on the same axes so you can compare their movement directionally.

# %%
import matplotlib.pyplot as plt
fx['EURUSD'].plot(figsize=(10,5))
plt.title('EURUSD Exchange Rates Over Time')
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.legend()
plt.show()

# %%
fx['USDCAD'].plot(figsize=(10,5))
plt.title('USDCAD Exchange Rates Over Time')
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
fx[['EURUSD', 'USDCAD']].plot(figsize=(12,6))

plt.title('EURUSD and USDCAD Exchange Rates Over Time')
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.legend()
plt.show()

# %% [markdown]
# # Task 3: Rolling features and validation
# Compute a 7‑day rolling mean and a 7‑day rolling standard deviation for the two currency pairs you selected. Store the rolling series with clear names. Print the first ten rows of the rolling results and confirm that missing values appear only where the window is incomplete.

# %%
rolling_mean_eurusd = fx['EURUSD'].rolling(window=7).mean()
rolling_mean_eurusd
# Out:
# Date
# 2025-01-02         NaN
# 2025-01-03         NaN
# 2025-01-06         NaN
# 2025-01-07         NaN
# 2025-01-08         NaN
#                 ...
# 2026-01-26    1.172971
# 2026-01-27    1.179303
# 2026-01-28    1.183734
# 2026-01-29    1.187270
# 2026-01-30    1.189669
# Name: EURUSD, Length: 280, dtype: float64

# %%
rolling_std_eurusd = fx['EURUSD'].rolling(window=7).std()
rolling_std_eurusd
# Out:
# Date
# 2025-01-02         NaN
# 2025-01-03         NaN
# 2025-01-06         NaN
# 2025-01-07         NaN
# 2025-01-08         NaN
#                 ...
# 2026-01-26    0.009746
# 2026-01-27    0.013530
# 2026-01-28    0.012981
# 2026-01-29    0.012683
# 2026-01-30    0.009816
# Name: EURUSD, Length: 280, dtype: float64

# %%
rolling_mean_usdcad = fx['USDCAD'].rolling(window=7).mean()
rolling_mean_usdcad
# Out:
# Date
# 2025-01-02         NaN
# 2025-01-03         NaN
# 2025-01-06         NaN
# 2025-01-07         NaN
# 2025-01-08         NaN
#                 ...
# 2026-01-26    1.380710
# 2026-01-27    1.375861
# 2026-01-28    1.371507
# 2026-01-29    1.366510
# 2026-01-30    1.363384
# Name: USDCAD, Length: 280, dtype: float64

# %%
rolling_std_usdcad = fx['USDCAD'].rolling(window=7).std()
rolling_std_usdcad
# Out:
# Date
# 2025-01-02         NaN
# 2025-01-03         NaN
# 2025-01-06         NaN
# 2025-01-07         NaN
# 2025-01-08         NaN
#                 ...
# 2026-01-26    0.008015
# 2026-01-27    0.010320
# 2026-01-28    0.011367
# 2026-01-29    0.012721
# 2026-01-30    0.010311
# Name: USDCAD, Length: 280, dtype: float64

# %%
rolling_std_usdcad[:10]
# Out:
# Date
# 2025-01-02         NaN
# 2025-01-03         NaN
# 2025-01-06         NaN
# 2025-01-07         NaN
# 2025-01-08         NaN
# 2025-01-09         NaN
# 2025-01-10    0.003854
# 2025-01-13    0.004047
# 2025-01-14    0.003233
# 2025-01-15    0.003156
# Name: USDCAD, dtype: float64

# %% [markdown]
# # Task 4: Simple baseline model
# Build a one‑step‑ahead baseline forecast for one selected currency pair by shifting the series by one day. Create a new column baseline_pred and compute the absolute error between the actual value and the baseline prediction. Then compute the mean absolute error and print it.

# %%
pair = 'EURUSD'
fx['baseline_pred'] = fx[pair].shift(1)
fx['abs_error'] = (fx[pair] - fx['baseline_pred']).abs()
mae = fx['abs_error'].mean()
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.004069426523297489

# %% [markdown]
# # Task 5: Short report with checks
# Write a small report dictionary that includes the chosen currency pairs, the rolling window size, the mean absolute error from the baseline model, and the date range of the dataset. Print the report and include one explicit check, such as confirming that the rolling window size you used matches the value in the report.

# %%
pairs = ['EURUSD', 'USDCAD']

# %%
rolling_window = 7

# %%
start_date = fx.index.min()
end_date = fx.index.max()

# %%
report = {
    "currency_pairs": {},
    "rolling_window_size": rolling_window,
    "date_range": (start_date, end_date)
}
for pair in pairs:
    fx[f"{pair}_baseline"] = fx[pair].shift(1)
    fx[f"{pair}_abs_error"] = (fx[pair] - fx[f"{pair}_baseline"]).abs()
    mae = fx[f"{pair}_abs_error"].mean()
    report["currency_pairs"][pair] = {
        "baseline_mae": mae
    }

# %%
print(report)
# Out:
# {'currency_pairs': {'EURUSD': {'baseline_mae': np.float64(0.004069426523297489)}, 'USDCAD': {'baseline_mae': np.float64(0.0035983870967741883)}}, 'rolling_window_size': 7, 'date_range': (Timestamp('2025-01-02 00:00:00'), Timestamp('2026-01-30 00:00:00'))}

# %%
assert rolling_window == report["rolling_window_size"], \
    "Rolling window size mismatch!"

print("Check passed")
# Out:
# Check passed
